# %% [markdown]
# **Lemma 1:**
#
# For any arbitrary configuration of a Rubik's Cube, in terms of permutations, the permutations of corners and edges have no intersection. Write the corner-permutations and edge-permutations as $CP$ and $EP$, then we have $sgn(CP)=sgn(EP)$.
#
# Moreover, $sgn(CP)=1$ if and only if this configuration is arrived after an even number of moves (i.e. has to be solved with an even number of times of moves).

# %% [markdown]
# **Proof:**
#
# Consider a single move (rotate one layer) effecting on $CP$. There are 4 corners in this layer, noted (only here, for convenience) $\{1, 2, 3, 4\}$, then this move results in a ***odd permutation*** $(1\ 2\ 3\ 4)$. And it is similar for a single move effecting on $EP$. Thus the parties of these two parts will keep consistent after a sequence of moves.
#
# Consider a sequence of moves, both its $CP$ and $EP$ parts can be decribed as conbinations of several odd permutations separately, thus the parity of this sequence maintains consistency with the number of moves.

# %% [markdown]
# **Lemma 2:**
#
# Let $C_o$, namely ***Cube Orientations*** in Rubik's Cube Group $C$, be containing all the configurations without changing the positions of any pieces. Then $C_o$ is a group and $C_o\unlhd C$.

# %% [markdown]
# **Proof:**
#
# By definition $C_o \subset C$. Now we prove $C_o$ is a group.
#
# (Identity) The solved cube $e \in C_o$, as $e$ does not change the positions.
#
# (Invertibility) For all $o\in C_o$, we have $o^{-1}\in C_o$ as $o$ does not change the positions and so does $o^{-1}$.
#
# (Closure) For any $o_1, o_2 \in C_o$, we have $o_1\cdot o_2 \in C_o$ as $o_1$ and $o_2$ do not change the positions.
#
# We conclude $C_o$ is a subgroup of $C$, i.e. $C_o \leq C$.
#
# For any $o \in C_o$ and $g \in C$, we know that $o$ has no effect on positions of pieces, we have $g^{-1} \cdot o \cdot g \in C_o$, since the effects on positions from $g$ and $g^{-1}$ cancel each other out, meaning $g^{-1} \cdot o \cdot g$ is also a oriented configuration. Thus $C_o$ is a normal subgroup, i.e. $C_o\unlhd C$.

# %% [markdown]
# **Lemma 3:**
#
# Given a Rubik's Cube with its Cube Group $C$. Let $S$ be a set consist of the centres of each pieces (regardless of orientation). We define $\Gamma : C \times S \rightarrow S$ is an action of $C$ over $S$, and $C_P = Im(\Gamma)$ namely ***Cube Positions***. Then we have $C/C_O \cong C_P$.

# %% [markdown]
# **Proof:**
#
# By the definition of $C_O$, we know that $C_O = ker(\Gamma)$. According to the ***Isomorphism theorem A***, with $C_O \unlhd C$, we have $C/C_O \cong C_P$.

# %% [markdown]
# **Lemma 4:**
#
# Given a Rubik's Cube with its Cube Group $C$, then $C_O \cong \mathbb{Z}_2^{11} \times \mathbb{Z}_3^7$.

# %% [markdown]
# **Proof:**
#
# Consider first $C_O$ acting over corners, note (and omit position changes) the orientations of corners as $x \in \mathbb{Z}_3$, thus all the $8$ corners can be described as $(x_1,x_2,\dots,x_8)$ \in \mathbb{Z}_3^8$. Now, we define function $\Gamma : C \rightarrow \mathbb{Z}_3^8$ to describe the rotations of corners with $8$ coordinates. Notice $\Gamma$ is not homomorphic.
#
# Define $\Lambda: \mathbb{Z}_3^8 \rightarrow \mathbb{Z}_3$ as $(x_1,x_2,\dots,x_8)\mapsto x_1 \circ x_2 \circ\dots\circ x_8$. Then $\lambda$ and $\lambda\circ\Gamma:G\rightarrow\mathbb{Z}_3$ are both homomorphic. Omit the proof here.
#
# By the definition of Cube's moves, we have
# $$
# \Gamma(U) = \Gamma(D) = ( (1), (1), \dots, (1) ) \\
# \Gamma(L) = ( (1\ 3\ 2), (1), (1\ 2\ 3), (1), (1\ 2\ 3), (1), (1), (1\ 3\ 2) ) \\
# \Gamma(R) = ( (1), (1\ 2\ 3), (1), (1\ 3\ 2), (1), (1\ 2\ 3), (1\ 3\ 2), (1) ) \\
# \Gamma(F) = ( (1\ 2\ 3), (1\ 3\ 2), (1), (1), (1\ 3\ 2), (1\ 2\ 3), (1), (1) ) \\
# \Gamma(B) = ( (1), (1), (1\ 3\ 2), (1\ 2\ 3), (1), (1), (1\ 3\ 2), (1\ 2\ 3) ),
# $$
# meaning $\Lambda\circ\Gamma(X)=(1)$ when $X\in\{U,D,F,B,R,L\}$.
#
# i.e., for any $g=\prod_{i=1}^8 X_i$ for $X_i\in\{U,D,F,B,R,L\}$, we have
# $$
# \Lambda\circ\Gamma(g)=\Lambda\circ\Gamma(\prod_{i=1}^8 X_i)=\Lambda(\Gamma(X_1)\circ\Gamma(X_2)\circ\dots\circ\Gamma(X_8))=(1),
# $$
# in other words, there is no configurations with only rotate one single corner.
#
# Thus $Im(\Lambda\circ\Gamma|_C)=\{(1)\}$, and $Ima(\Lambda\circ\Gamma|_{C_O})\subseteq Ima(\Lambda\circ\Gamma|_C)=\{(1)\}$ as $C_O \subseteq C$. Since $Ima(\Lambda\circ\Gamma|_{C_O})$ is not empty, $Ima(\Lambda\circ\Gamma|_{C_O})=\{(1)\}$. With the fact that $\Gamma:C_O\rightarrow \mathbb{Z}_3^8$ is homomorphic and $Ker(\Gamma|_{C_O})=\{(1)\}$, we can conclude that $\Gamma$ over $O$ is injective and homomorphic. i.e., for all $o \in C_O$, we have $\Gamma(o)=(x_1,x_2,\dots,x_7,(x_1\circ x_2\circ\dots\circ x_7)^{-1})$. Intuitively, the last corner will be definite whenerver the first seven corners are fixed.
#
# There already exists an operation (see the Sage block below) to change the orientations of only 2 corners, inferring all the configurations in the form above are achievable, thus the action of $C_O$ over corners has the group structure $\mathbb{Z}_3^7$.

# %%
RubiksCube("B*R'*D^2*R*B'*U^2*B*R'*D^2*R*B'*U^2").plot3d()
# Out:
# Graphics3d Object

# %% [markdown]
# Similarly, we can conclude that the action of $C_O$ has the structure $\mathbb{Z}_2^{11}$ over edges, regarding the existance of operations only flipping 2 edges like below.

# %%
RubiksCube("R*U*D*B^2*U^2*B'*U*B*U*B^2*D'*R'*U'").plot3d()
# Out:
# Graphics3d Object

# %% [markdown]
# As a result, consider $C_O$ acting over $C$, we could conclude that $C_O\cong \mathbb{Z}_2^{11}\times\mathbb{Z}_3^{7}$.

# %% [markdown]
# **Lemma 5:**
#
# Given a Rubik's Cube Group $C$, define $CE=\{\text{All the configurations with even number of moves}\}$. Then the action of $CE$ over $C_P$ has the group structure $A_8\times A_{12}$.

# %% [markdown]
# **Proof:**
#
# Consider *only* the action of $CE$ over the corners positions, note (only here, for convenience) corners as $S_C=\{1,2,\dots,8\}$ and write the action of $CE$ over $S_C$ as $\Psi$. As we already know, by *Lemma 1*, $CE$ acting over $S_C$ is an even permutation, since the moves have an even number. Thus we know that $Im(\psi|_{CE})\leq A_8$.
#
# Now we have to find a group $F\leq CE$, such that $\Gamma(f)=((1),\dots,(1))$ for $f\in F$, *where the definition of $\Gamma$ is in the proof of Lemma 4*, and $Im(\Psi|_F)=A_8$. Intuitively, $F$ contains only operations $f$-s which do not change orientations but only change positions. And for all perputations in $A_8$, we can find an unique and distinct configuration for each. We know that such an $F$ exists, but its construction as well as proof are omitted here. *(If you are familiar with blindfolded solving, you could also complete this construction.)*
#
# Hence we know that $Im(\Psi|_{CE}) = Im(\Psi|_F) \cong A_8$ and $F \cong A_8$.
#
# Similarly, consider $CE$ over edges, note edges as $S_E=\{1,2,\dots,12\}$ and write the action as $\Phi$. A group $H\leq CE$ may also be constructed such that $Im(\Phi|_{CE}) = Im(\Phi|_H) \cong A_{12}$ and $H \cong A_{12}$.
#
# Thus the action of $CE$ over the positions of pieces of cube $C$ has the structure $A_8\times A_{12}$.

# %% [markdown]
# **Lemma 6:**
#
# Given a Rubik's Cube Group $C$ with standard moves $\{U,D,F,B,R,L\}$.
#
# Let $t = RUR^3U^3R^3FR^2U^3R^3U^3RUR^3F^3 \in C$, $T = \{t,e\}$, then $C=CE\rtimes T$.
#
# ($t$ is an operation to swap a pair of corners and a pair of edges simultaneously as below)

# %%
RubiksCube("R*U*R^3*U^3*R^3*F*R^2*U^3*R^3*U^3*R*U*R^3*F^3").plot3d()
# Out:
# Graphics3d Object

# %% [markdown]
# **Proof:**
#
# First we prove $CE\unlhd C$:
#
# Let $g\in C, a\in CE$. Since $c$ has an even number of moves, so do $g^{-1}\circ a\circ g$, and thus $g^{-1}\circ a\circ g \in CE$. Hence $CE\unlhd C$.
#
# As $t$ has an odd number of moves, $t \notin CE$, and thus $CE \cap \{t,e\} = \{e\}$. Since $CE\{t,e\}\subseteq C$, with $|CE|=|C|/2$ *(by definition of $CE$)*, we can conclude that $|CE|\cdot|{t,e}|=|C|$, and thus $CE\{t,e\} = C$.
#
# Hence $C=CE\rtimes T$.

# %% [markdown]
# **Lemma 7:**
#
# Given Rubiks' Cube Group $C$, then $C \cong (\mathbb{Z}_2^{11}\times \mathbb{Z}_3^7) \rtimes (A_8\times A_{12}\rtimes \mathbb{Z}_2)$.

# %% [markdown]
# **Proof:**
#
# By *Lemma 3* we have $C = C_O \cdot C_P$, and since $C_O\cap C_P = \{e\}$, we have $C = C_O \rtimes C_P$.
#
# Let $CE_P = Im(\Theta|_{CE})$ where $\Theta$ is an action of $CE$ over $C_P$, and by *Lemma 5* we have $CE_P\cong A_8\times A_{12}$.
#
# Recall $T=\{t,e\}$, where $t = RUR^3U^3R^3FR^2U^3R^3U^3RUR^3F^3 \notin C_O$, meaning $C_O\cap T = \{e\}$. i.e., for all $o\in C_O$, we have $o \in CE$, since $C = CE \rtimes T$ by *Lemma 6*.
#
# By definition we have $|C_P|=2|CE_P|$ and $CE_P\leq C_P$. Also, as *t* has an add numver of moves, similarly to *Lemma 6* we have $CE_P\cap T=\{e\}$. Regarding to the fact that for all $g\in C_P, a\in CE_P$, we have $g^{-1}\circ a\circ g \in CE_P$, meaning $CE_P\unlhd C_P$, with $C_P/CE_P \cong \mathbb{Z}_2 \cong T$. Hence $C_P \cong CE_P \rtimes T$.
#
# As a result, $C = C_O \rtimes C_P \cong C_O \rtimes (CE_P \rtimes T) \cong (\mathbb{Z}_2^{11}\times \mathbb{Z}_3^7) \rtimes (A_8\times A_{12}\rtimes \mathbb{Z}_2)$.

# %% [markdown]
# **Conclusion:**
#
# According to ***Lemma 7***, we have already split a Rubik's Cube Group into several familiar groups. Now we can calculate its size, which demonstrates the amount of all legal configuration of a Rubik's Cube. The result is
#
# $$|C|=|\mathbb{Z}_2|^{11}\cdot |\mathbb{Z}_3|^7\cdot |A_8|\cdot |A_{12}|\cdot |\mathbb{Z}_2|=43252003274489856000.$$
